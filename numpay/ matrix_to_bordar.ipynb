# %%
import numpy as np

m = np.array([
    [1, 2, 3],
    [4, 5, 6]
    ])
b = np.array([7, 8, 9])

result = np.dot(m, b)
print("نتیجه dot product:", result)
print("نتیجه:", np.dot(m, b))
# Out:
# نتیجه dot product: [ 50 122]
# نتیجه: [ 50 122]
