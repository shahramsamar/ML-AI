# %%
import numpy as np

A = np.array([
    [1, 2, 3],
    [4, 5, 6]
    ])
B = np.array([
    [7, 8],
    [9, 10],
    [11, 12]
    ])

result = np.dot(A, B)
print("result dot product:", result)
print("result:", np.dot(A, B))
# Out:
# result dot product: [[ 58  64]
#  [139 154]]
# result: [[ 58  64]
#  [139 154]]
