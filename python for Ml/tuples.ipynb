# %%
#tuples

# %%
tuple1 = ('red', 'green', 'blue', 'yellow')
tuple2 = ('banana', 'cherry', 'orange', 'kiwi', 'apple')
tuple3 = (11, 15, 17, 20)
tuple4 = (True, False, False)
tuple5 = ('Ali', 34, True, 'male', 18.5)

# %%
 t = (5, 12, 7, 20, 19, 13, 15, 17, 16, 18, 20, 17)

# %%
len(t)
# Out:
# 12

# %%
t.count(20)
# Out:
# 2

# %%
t.index(20)
# Out:
# 3

# %%
min(t)
# Out:
# 5

# %%
max(t)
# Out:
# 20

# %%
for x in t:
    print(x)
# Out:
# 5
# 12
# 7
# 20
# 19
# 13
# 15
# 17
# 16
# 18
# 20
# 17

# %%
for i in range(len(t)):
    print(t[i])
# Out:
# 5
# 12
# 7
# 20
# 19
# 13
# 15
# 17
# 16
# 18
# 20
# 17

# %%
20 in t
# Out:
# True

# %%
tuple2 = (11, 16)
tuple3 = t + tuple2
tuple3
# Out:
# (5, 12, 7, 20, 19, 13, 15, 17, 16, 18, 20, 17, 11, 16)

# %%
t

# %%
(x, y, *z) = t
x
# Out:
# 5
