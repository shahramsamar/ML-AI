# %%
# Stirng

# %%
mtsring = "Hello, Python!"

# %%
mystrin = """Python is powerfull... and fast;
             easy to learn;
             is frendly. """

# %%
s1 = 'Shahram'
s2 = 'Samar'
sum = s1 + ' ' + s2
print(sum)
# Out:
# ShahramSamar

# %%
len(sum)
# Out:
# 12

# %%
sum[-1]
# Out:
# 'r'

# %%
sum[0]
# Out:
# 'S'

# %%
for char in sum:
    print(char)
# Out:
# S
# h
# a
# h
# r
# a
# m
# S
# a
# m
# a
# r

# %%
'Sha' in sum
# Out:
# True

# %%
sum[7:12]
# Out:
# 'Samar'

# %%
x = 'abcd'
x [::-1]
# Out:
# 'dcba'

# %%
sum.upper()
# Out:
# 'SHAHRAMSAMAR'

# %%
sum.lower()
# Out:
# 'shahramsamar'

# %%
s = sum
s.count("h")
# Out:
# 2

# %%
s.find("a")
# Out:
# 2

# %%
s.index("a")
# Out:
# 2

# %%
sentence = "Python is a programming language"
t = sentence.replace("Python", "C++")
t
# Out:
# 'C++ is a programming language'

# %%
words = sentence.split()
words
# Out:
# ['Python', 'is', 'a', 'programming', 'language']

# %%
s = " ".join(words)
s
# Out:
# 'Python is a programming language'

# %%
s = " shahram "
s = s.strip()
s
# Out:
# 'shahram'

# %%
url = "https://www.shahramsamar.ir"
if url.startswith("https://")
    print("Safe"
