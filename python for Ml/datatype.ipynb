# %%
int, float, str, bool,
list, tuple, set, dict,
complex
# Out:
# (int, float, str, bool)

# %%
type(13) #int
# Out:
# int

# %%
type(13.5) #float
# Out:
# float

# %%
type('shahram') #str
# Out:
# str

# %%
type(True) #bool
# Out:
# bool

# %%
type([11, 20, 13]) #list
# Out:
# list

# %%
type((11, 20, 13)) #tuple
# Out:
# tuple

# %%
type({11, 20, 13}) #set
# Out:
# set

# %%
type({'a':2, 'b':3}) #dict
# Out:
# dict

# %%
type(1 + 3j) #complex
# Out:
# complex
