# %%
# list

# %%
list1 = [13, 11, 15, 10, 14, 12]
list2 = ["Kiwi", "apple", "banana", "cherry"]
list3 = ["shahram", 51, True]
lst = [17, 11, 15, 10, 14, 12]

# %%
len(lst)
# Out:
# 6

# %%
lst[0]
# Out:
# 17

# %%
lst[0] = 50
lst
# Out:
# [50, 11, 15, 10, 14, 12]

# %%
for item in lst:
    print(item)
# Out:
# 50
# 11
# 15
# 10
# 14
# 12

# %%
for i in range(len(lst)):
    print(lst[i])
# Out:
# 50
# 11
# 15
# 10
# 14
# 12

# %%
lst[2:5]
# Out:
# [15, 10, 14]

# %%
lst[-4:5]
# Out:
# [15, 10, 14]

# %%
lst.index(12)
# Out:
# 5

# %%
lst.append(16)
lst
# Out:
# [50, 11, 15, 10, 14, 12, 16]

# %%
lst.insert(2,13)
lst
# Out:
# [50, 11, 13, 15, 10, 14, 12, 16]

# %%
lst.count(13)
# Out:
# 1

# %%
lst.remove(13)
lst
# Out:
# [50, 11, 15, 10, 14, 12, 16]

# %%
x = lst.pop()
print(x)
lst
# Out:
# [50, 11, 15, 10, 14, 12]
