# %%
Arithmetic #عملگر ریاضی

# %%
print(1 + 2)
print(3 - 1)
print(4 * 2)
print(2 ** 3) #توان
print(10 / 3) #تقسیم
print(10 // 3) #تقسیم صحیح
print(10 % 3) #باقی مانده
# Out:
# 3
# 2
# 8
# 8
# 3.3333333333333335
# 3
# 1

# %%
Assignment # انتساب

# %%
x = 5
x += 3
x -= 3
x *= 3
x **=3
x /= 3
x //= 3

# %%
Comparisons #مقایسه ای
<, <=, >, >=, ==, !=

# %%
print(1 == 2)
print(1 != 2)
print(1 < 2)
print(1 > 2)
print(1 <= 2)
print(1 >= 2)
# Out:
# False
# True
# True
# False
# True
# False

# %%
Logical # عملگر منطقی
and , or , not

# %%
print(3 > 2 and 4 < 3)
print(3 > 2 or 4 > 3)
print(not 3 > 2)
# Out:
# False
# True
# False

# %%
Bitwise #

# %%
Memnership(in, notin) #عملگر های  عضویت

# %%
identify(is, isnot) #  بررسی برابری

# %%
operator predecdence
