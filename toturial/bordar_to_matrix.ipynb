# %%
import numpy as np

b = np.array([7, 8])

m = np.array([
    [1, 2, 3],
    [4, 5, 6]
    ])


result = np.dot(b, m)
print("result dot product:", result)
print("result:", np.dot(b, m))
# Out:
# result dot product: [39 54 69]
# result: [39 54 69]
