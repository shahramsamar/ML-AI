# %%
import pandas as pd #pandas

# %%
import numpy as np #numpy

# %%
import matplotlib.pyplot as pt

# %%
course = {
    'code' :['c100', 'py100'],
    'name' : ['c++', 'python'],
    'rating' : [4.8, 4.9],
    'price' :[100, 200]
}

# %%
df = pd.DataFrame(course) #convert to datafram

# %%
df # print
# Out:
#     code    name  rating  price
# 0   c100     c++     4.8    100
# 1  py100  python     4.9    200

# %%
df.to_csv('/home/shahram/Desktop:f.csv', index=False) # for save

# %%
x = pd.read_csv('/home/shahram/Desktop/Ml-AI/faradars.csv') # for read file

# %%
x
# Out:
#       code                                           name  rating  n_rating  \
# 0   FD-101                                            C++     4.6       720
# 1   FD-102                 Python with practical examples     4.6       611
# 2   FD-103                     Python for teenagers_part1     4.7       147
# 3   FD-104                     Python for teenagers_part2     4.9        20
# 4   FD-105           Additional Python- Code Optimization     4.6        43
# 5   FD-106            JavaScript_Introductory to advanced     4.4       116
# 6   FD-107                  Assembly language programming     4.5        36
# 7   FD-108                           Qt Framework for C++     4.3        44
# 8   FD-109                                Data structures     4.6       166
# 9   FD-110                       Data structures with C++     4.6        65
# 10  FD-111                    Data structures with Python     4.7        69
# ...
